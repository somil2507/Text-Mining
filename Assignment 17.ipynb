# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score

# %%
s_train = pd.read_csv("E:\\ExcelR\\Assingment\\Assignment 17\\SalaryData_Train.csv")
s_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0            Adm-clerical   Not-in-family   White     Male         2174
# 1         Exec-managerial         Husband   White     Male            0
# 2       Handlers-cleaners   Not-in-family   White     Male            0
# 3       Handlers-cleaners         Husband   Black     Male            0
# 4          Prof-specialty            Wife   Black   Female            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 0                0            40   United-States   <=50K
# 1                0            13   United-States   <=50K
# 2                0            40   United-States   <=50K
# 3                0            40   United-States   <=50K
# 4                0            40            Cuba   <=50K
# ...            ...           ...             ...     ...
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K
#
# [30161 rows x 14 columns]

# %%
s_test = pd.read_csv("E:\\ExcelR\\Assingment\\Assignment 17\\SalaryData_Train.csv")
s_test
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0            Adm-clerical   Not-in-family   White     Male         2174
# 1         Exec-managerial         Husband   White     Male            0
# 2       Handlers-cleaners   Not-in-family   White     Male            0
# 3       Handlers-cleaners         Husband   Black     Male            0
# 4          Prof-specialty            Wife   Black   Female            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 0                0            40   United-States   <=50K
# 1                0            13   United-States   <=50K
# 2                0            40   United-States   <=50K
# 3                0            40   United-States   <=50K
# 4                0            40            Cuba   <=50K
# ...            ...           ...             ...     ...
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K
#
# [30161 rows x 14 columns]

# %%
s_train.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
s_test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
s_train.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
s_test.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
s_train = s_train.apply(LabelEncoder().fit_transform)

s_test = s_test.apply(LabelEncoder().fit_transform)

# %%
s_train.dtypes
# Out:
# age              int64
# workclass        int64
# education        int64
# educationno      int64
# maritalstatus    int64
# occupation       int64
# relationship     int64
# race             int64
# sex              int64
# capitalgain      int64
# capitalloss      int64
# hoursperweek     int64
# native           int64
# Salary           int64
# dtype: object

# %%
s_test.dtypes
# Out:
# age              int64
# workclass        int32
# education        int32
# educationno      int64
# maritalstatus    int32
# occupation       int32
# relationship     int32
# race             int32
# sex              int32
# capitalgain      int64
# capitalloss      int64
# hoursperweek     int64
# native           int32
# Salary           int32
# dtype: object

# %%
s_train.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   22          5          9           12              4           0
# 1   33          4          9           12              2           3
# 2   21          2         11            8              0           5
# 3   36          2          1            6              2           5
# 4   11          2          9           12              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1           24            0            39      37
# 1             0     4    1            0            0            12      37
# 2             1     4    1            0            0            39      37
# 3             0     2    1            0            0            39      37
# 4             5     2    0            0            0            39       4
#
#    Salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
s_test.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   22          5          9           12              4           0
# 1   33          4          9           12              2           3
# 2   21          2         11            8              0           5
# 3   36          2          1            6              2           5
# 4   11          2          9           12              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1           24            0            39      37
# 1             0     4    1            0            0            12      37
# 2             1     4    1            0            0            39      37
# 3             0     2    1            0            0            39      37
# 4             5     2    0            0            0            39       4
#
#    Salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print("Skewness of the Salary target variable for train dataset is : %f " %s_train["Salary"].skew())

print("Kurtosis of the Salary target variable for train dataset is : %f " %s_train["Salary"].kurt())
# Out:
# Skewness of the Salary target variable for train dataset is : 1.161357
# Kurtosis of the Salary target variable for train dataset is : -0.651292

# %%
print("Skewness of the Salary target variable for test dataset is : %f " %s_test["Salary"].skew())

print("Kurtosis of the Salary target variable for test dataset is : %f " %s_test["Salary"].kurt())
# Out:
# Skewness of the Salary target variable for test dataset is : 1.161357
# Kurtosis of the Salary target variable for test dataset is : -0.651292

# %%
X_train= s_train.drop(['workclass','education','relationship','occupation','native','maritalstatus','sex','race'],axis=1)
Y_train= s_train['Salary']
print(np.unique(Y_train))
X_train.head()
# Out:
# [0 1]
#    age  educationno  capitalgain  capitalloss  hoursperweek  Salary
# 0   22           12           24            0            39       0
# 1   33           12            0            0            12       0
# 2   21            8            0            0            39       0
# 3   36            6            0            0            39       0
# 4   11           12            0            0            39       0

# %%
X_test= s_test.drop(['workclass','education','relationship','occupation','native','maritalstatus','sex','race'],axis=1)
Y_test= s_test['Salary']
print(np.unique(Y_test))
X_test.head()
# Out:
# [0 1]
#    age  educationno  capitalgain  capitalloss  hoursperweek  Salary
# 0   22           12           24            0            39       0
# 1   33           12            0            0            12       0
# 2   21            8            0            0            39       0
# 3   36            6            0            0            39       0
# 4   11           12            0            0            39       0

# %%
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((30161, 6), (30161,), (30161, 6), (30161,))

# %%
sns.countplot(s_train["Salary"])
plt.show()

# %%
sns.countplot(s_test["Salary"])
plt.show()

# %%
plt.style.use('seaborn')
s_train[["age", "educationno", "capitalgain","capitalloss","hoursperweek"]].hist(bins = 25, figsize = (20,15))
plt.show()

# %%
plt.style.use('seaborn')
s_test[["age", "educationno", "capitalgain","capitalloss","hoursperweek"]].hist(bins = 25, figsize = (20,15))
plt.show()

# %%
sns.heatmap(s_train.corr(),annot=True)
plt.show()

# %%
sns.heatmap(s_test.corr(),annot = True)
plt.show()

# %%
from sklearn.naive_bayes import MultinomialNB as mb
from sklearn.naive_bayes import GaussianNB as gb

# %%
clmb = mb()
clgb = gb()

# %%
clmb.fit(X_train,Y_train)
# Out:
# MultinomialNB()

# %%
train_pred_mb = clmb.predict(X_train)
accuracy_train_mb = np.mean(train_pred_mb == Y_train)

test_pred_mb = clmb.predict(X_test)
accuracy_test_mb = np.mean(test_pred_mb==Y_test)

# %%
accuracy_train_mb
# Out:
# 0.7803123238619409

# %%
accuracy_test_mb
# Out:
# 0.7803123238619409

# %%
clgb.fit(X_train,Y_train) 
train_pred_gb = clgb.predict(X_train)
accuracy_train_gb = np.mean(train_pred_gb == Y_train) 

test_pred_gb = clgb.predict(X_test)
accuracy_test_gb = np.mean(test_pred_gb == Y_test)

# %%
accuracy_train_gb
# Out:
# 1.0

# %%
accuracy_test_gb
# Out:
# 1.0

# %%
print(classification_report(Y_test,test_pred_mb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86     22653
#            1       0.62      0.31      0.41      7508
#
#     accuracy                           0.78     30161
#    macro avg       0.71      0.62      0.64     30161
# weighted avg       0.76      0.78      0.75     30161
